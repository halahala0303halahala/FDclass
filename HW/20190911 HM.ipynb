# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
x=np.linspace(-5,5,100)
y1=np.tan(x)
y2=-np.tan(x-np.pi)
y1[y1>100]=np.inf
y1[y1<-100]=-np.inf
y2[y2>100]=np.inf
y2[y2<-100]=-np.inf
plt.plot(x,y1)
plt.plot(x,y2)
